# %%
import pandas as pd

# %%
df = pd.read_csv("messy.csv")
df
# Out:
#           Time Stamp,"Time Zone","Name","PTID";"Load"
# 0       01/01/2004 00:00:00,"EST","CAPITL",61757,1015
# 1       01/01/2004 00:00:00,"EST","CAPITL",61757,1015
# 2       01/01/2004 00:00:00,"EST","CENTRL",61754,1651
# 3        01/01/2004 00:00:00,"EST","DUNWOD",61760,618
# 4        01/01/2004 00:00:00,"EST","GENESE",61753,972
# 5       01/01/2004 00:00:00,"EST","HUD VL",61758,1120
# 6        01/01/2004 00:00:00,"EST","MHK VL",61756,645
# 7        01/01/2004 00:00:00,"EST","MILLWD",61759,223
# 8     01/01/2004 00:00:00,"EST","N.Y.C._LONGIL",,7267
# 9         01/01/2004 00:00:00,"EST","NORTH",61755,622
# 10        01/01/2004 00:00:00,"EST","WEST",61752,1591
# 11      01/01/2004 00:00:47,"EST","CAPITL",61757,1016
# 12      01/01/2004 00:00:47,"EST","CENTRL",61754,1653
# 13       01/01/2004 00:00:47,"EST","DUNWOD",61760,615
# 14       01/01/2004 00:00:47,"EST","GENESE",61753,985
# 15      01/01/2004 00:00:47,"EST","HUD VL",61758,1106
# ...

# %%
df.dtypes
# Out:
# Time Stamp,"Time Zone","Name","PTID";"Load"    object
# dtype: object
